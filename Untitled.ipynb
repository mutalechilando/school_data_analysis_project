# %%
import pandas as pd

student = pd.read_excel('students.xlsx')
df = pd.DataFrame(student)
df.describe()
# Out:
#              Age  Math_Score  English_Score  Science_Score  Attendance_%  \
# count  40.000000   45.000000      48.000000      42.000000     50.000000
# mean   17.750000   71.671111      63.800000      61.457143     85.292000
# std     1.171236   16.704567      16.212288      21.624762      8.217424
# min    16.000000   38.400000      40.500000      30.900000     70.300000
# 25%    17.000000   60.100000      49.025000      44.875000     78.750000
# 50%    18.000000   68.900000      63.800000      57.300000     85.800000
# 75%    19.000000   88.300000      72.400000      78.225000     90.600000
# max    19.000000   98.400000      93.500000      99.100000     99.200000
#
#        Average_Score
# count      50.000000
# mean       65.012000
# std        10.916762
# min        39.300000
# 25%        58.545833
# 50%        63.666667
# 75%        72.604167
# max        89.666667

# %%
print(df['Age'].mean())
# Out:
# 17.75

# %%
print(df['Age'].median())
# Out:
# 18.0

# %%
df.sort_values(by='Age')
# Out:
#    Student_ID              Name   Age  Gender      Class  Math_Score  \
# 0        S001       Grace Mwila  16.0    Male  Grade 12A        68.9
# 3        S004        James Zulu  16.0  Female  Grade 12B        82.4
# 7        S008     Patrick Phiri  16.0  Female  Grade 12A        54.5
# 4        S005       Chipo Tembo  16.0    Male  Grade 11A         NaN
# 10       S011       Ruth Bwalya  16.0  Female  Grade 12A        83.0
# 36       S037     Ronald Chansa  16.0    Male  Grade 12B        78.0
# 29       S030        Diana Zulu  16.0    Male  Grade 12B        65.9
# 23       S024    Deborah Mutale  16.0  Female  Grade 11B        74.0
# 44       S045    Justine Mwansa  16.0    Male  Grade 11B        60.1
# 18       S019       Elias Tembo  17.0  Female  Grade 11A        69.2
# 12       S013     Agnes Kapenda  17.0    Male  Grade 12B         NaN
# 14       S015   Mirriam Kalunga  17.0    Male  Grade 12A         NaN
# 27       S028     Rebecca Banda  17.0    Male  Grade 12A        55.0
# 15       S016  Josephine Mulilo  17.0  Female  Grade 11A        89.2
# 49       S050       Agnes Mumba  17.0    Male  Grade 11A        38.4
# 17       S018  Catherine Nsofwa  18.0    Male  Grade 11B        57.8
# 34       S035     Rodrick Phiri  18.0    Male  Grade 11B        70.4
# 33       S034      Agatha Lungu  18.0  Female  Grade 11B        98.4
# 24       S025      David Mwansa  18.0    Male  Grade 12A        76.2
# 25       S026   Loveness Chanda  18.0    Male  Grade 11A        64.3
# 20       S021      George Lungu  18.0    Male  Grade 12B        90.0
# 40       S041       Ethel Mwape  18.0    Male  Grade 11B        42.7
# 8        S009     Esther Chanda  18.0  Female  Grade 12B        66.5
# 26       S027    Sydney Mulenga  18.0  Female  Grade 11B        67.6
# 42       S043      Tobias Lungu  18.0    Male  Grade 12B        42.7
# 43       S044      Bridget Zulu  18.0    Male  Grade 11A        69.6
# 22       S023     Mathews Zimba  19.0  Female  Grade 11A         NaN
# 13       S014   Lawrence Njobvu  19.0    Male  Grade 12B        97.1
# 11       S012      Kelvin Mwape  19.0    Male  Grade 12A        48.0
# 1        S002        John Banda  19.0    Male  Grade 11A        51.8
# 2        S003        Mary Phiri  19.0    Male  Grade 11A        57.0
# 6        S007     Natasha Lungu  19.0  Female  Grade 11A        64.1
# 37       S038      Gloria Mbewe  19.0    Male  Grade 11A        92.8
# 35       S036        Ivy Kaluba  19.0    Male  Grade 11A        63.9
# 32       S033   Kenneth Kapenda  19.0    Male  Grade 11B        49.7
# 21       S022    Ireen Chileshe  19.0    Male  Grade 12B        68.8
# 19       S020     Tandiwe Phiri  19.0    Male  Grade 12A        88.3
# 41       S042   Martin Chileshe  19.0  Female  Grade 11A        89.6
# 45       S046       Linda Tembo  19.0    Male  Grade 11B        61.2
# 48       S049        Gift Banda  19.0  Female  Grade 11A        80.4
# 5        S006     Brian Mulenga   NaN    Male  Grade 12A        88.2
# 9        S010       Henry Mumba   NaN    Male  Grade 12A        88.5
# 16       S017        Paul Zimba   NaN    Male  Grade 11A         NaN
# 28       S029      Andrew Mwape   NaN    Male  Grade 12A        66.9
# 30       S031      Felix Chirwa   NaN    Male  Grade 12A        94.1
# 31       S032       Faith Mumba   NaN  Female  Grade 11B        97.1
# 38       S039      Allan Chisha   NaN  Female  Grade 11B        96.6
# 39       S040     Naomi Katongo   NaN    Male  Grade 11A        63.0
# 46       S047    Benjamin Phiri   NaN    Male  Grade 11B        58.7
# 47       S048  Precious Mulenga   NaN  Female  Grade 12A        94.6
#
#     English_Score  Science_Score  Attendance_%  Average_Score  Passed
# 0            44.7           36.0          88.4      49.866667   False
# 3             NaN           32.2          71.6      57.300000    True
# 7            81.1            NaN          85.9      67.800000    True
# 4            44.6           34.0          70.7      39.300000   False
# 10           67.5           36.1          75.5      62.200000    True
# 36           56.2           59.9          96.3      64.700000    True
# 29           51.0            NaN          96.9      58.450000    True
# 23            NaN           53.0          96.6      63.500000    True
# 44           53.7           77.7          89.4      63.833333    True
# 18           69.1           44.7          90.6      61.000000    True
# 12           71.9           59.6          81.7      65.750000    True
# 14           71.2           42.2          73.4      56.700000    True
# 27           77.6           90.7          85.7      74.433333    True
# 15           63.6           98.1          83.3      83.633333    True
# 49           67.0           79.9          90.4      61.766667    True
# 17           59.1           50.5          81.4      55.800000    True
# 34           92.6           99.1          89.2      87.366667    True
# 33           42.4            NaN          85.2      70.400000    True
# 24           88.6           64.5          88.6      76.433333    True
# 25           42.4           45.4          90.5      50.700000    True
# 20           84.9           54.7          94.2      76.533333    True
# 40           92.4           49.3          86.7      61.466667    True
# 8            66.4           43.6          70.3      58.833333    True
# 26           66.7           87.3          72.1      73.866667    True
# 42           72.3           73.7          76.8      62.900000    True
# 43           92.5           32.3          85.0      64.800000    True
# 22           44.4            NaN          98.2      44.400000   False
# 13           49.4            NaN          87.2      73.250000    True
# 11           41.8            NaN          72.7      44.900000   False
# 1            93.5           98.9          73.1      81.400000    True
# 2            80.0           69.0          86.7      68.666667    True
# 6            40.7           47.9          92.2      50.900000    True
# 37           41.3           47.2          90.6      60.433333    True
# 35           47.9           58.3          78.2      56.700000    True
# 32           46.2           89.8          88.3      61.900000    True
# 21           69.0           30.9          95.6      56.233333    True
# 19           88.1           92.6          84.2      89.666667    True
# 41           69.7           38.3          99.2      65.866667    True
# 45           64.0            NaN          95.0      62.600000    True
# 48           85.1           33.5          78.9      66.333333    True
# 5            72.7           94.9          79.0      85.266667    True
# 9            57.0           78.4          85.3      74.633333    True
# 16           61.4           92.9          78.4      77.150000    True
# 28           40.5           75.3          78.5      60.900000    True
# 30           45.9           68.4          78.7      69.466667    True
# 31           57.3           48.2          93.8      67.533333    True
# 38           60.2           55.2          79.5      70.666667    True
# 39           61.7           56.3          94.3      60.333333    True
# 46           55.5            NaN          83.1      57.100000    True
# 47           69.6           60.7          97.5      74.966667    True

# %%
print(df['Age'].mode())
# Out:
# 0    19.0
# Name: Age, dtype: float64

# %%
print(df['Age'].var())
# Out:
# 1.3717948717948718

# %%
print(df['Age'].std())
# Out:
# 1.1712364713391024

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student_ID     50 non-null     object
#  1   Name           50 non-null     object
#  2   Age            40 non-null     float64
#  3   Gender         50 non-null     object
#  4   Class          50 non-null     object
#  5   Math_Score     45 non-null     float64
#  6   English_Score  48 non-null     float64
#  7   Science_Score  42 non-null     float64
#  8   Attendance_%   50 non-null     float64
#  9   Average_Score  50 non-null     float64
#  10  Passed         50 non-null     bool
# dtypes: bool(1), float64(6), object(4)
# memory usage: 4.1+ KB

# %%
df.describe()
# Out:
#              Age  Math_Score  English_Score  Science_Score  Attendance_%  \
# count  40.000000   45.000000      48.000000      42.000000     50.000000
# mean   17.750000   71.671111      63.800000      61.457143     85.292000
# std     1.171236   16.704567      16.212288      21.624762      8.217424
# min    16.000000   38.400000      40.500000      30.900000     70.300000
# 25%    17.000000   60.100000      49.025000      44.875000     78.750000
# 50%    18.000000   68.900000      63.800000      57.300000     85.800000
# 75%    19.000000   88.300000      72.400000      78.225000     90.600000
# max    19.000000   98.400000      93.500000      99.100000     99.200000
#
#        Average_Score
# count      50.000000
# mean       65.012000
# std        10.916762
# min        39.300000
# 25%        58.545833
# 50%        63.666667
# 75%        72.604167
# max        89.666667

# %%
df.value_counts()
# Out:
# Student_ID  Name              Age   Gender  Class      Math_Score  English_Score  Science_Score  Attendance_%  Average_Score  Passed
# S001        Grace Mwila       16.0  Male    Grade 12A  68.9        44.7           36.0           88.4          49.866667      False     1
# S002        John Banda        19.0  Male    Grade 11A  51.8        93.5           98.9           73.1          81.400000      True      1
# S003        Mary Phiri        19.0  Male    Grade 11A  57.0        80.0           69.0           86.7          68.666667      True      1
# S007        Natasha Lungu     19.0  Female  Grade 11A  64.1        40.7           47.9           92.2          50.900000      True      1
# S009        Esther Chanda     18.0  Female  Grade 12B  66.5        66.4           43.6           70.3          58.833333      True      1
# S011        Ruth Bwalya       16.0  Female  Grade 12A  83.0        67.5           36.1           75.5          62.200000      True      1
# S016        Josephine Mulilo  17.0  Female  Grade 11A  89.2        63.6           98.1           83.3          83.633333      True      1
# S018        Catherine Nsofwa  18.0  Male    Grade 11B  57.8        59.1           50.5           81.4          55.800000      True      1
# S019        Elias Tembo       17.0  Female  Grade 11A  69.2        69.1           44.7           90.6          61.000000      True      1
# S020        Tandiwe Phiri     19.0  Male    Grade 12A  88.3        88.1           92.6           84.2          89.666667      True      1
# S021        George Lungu      18.0  Male    Grade 12B  90.0        84.9           54.7           94.2          76.533333      True      1
# S022        Ireen Chileshe    19.0  Male    Grade 12B  68.8        69.0           30.9           95.6          56.233333      True      1
# S025        David Mwansa      18.0  Male    Grade 12A  76.2        88.6           64.5           88.6          76.433333      True      1
# S026        Loveness Chanda   18.0  Male    Grade 11A  64.3        42.4           45.4           90.5          50.700000      True      1
# S027        Sydney Mulenga    18.0  Female  Grade 11B  67.6        66.7           87.3           72.1          73.866667      True      1
# S028        Rebecca Banda     17.0  Male    Grade 12A  55.0        77.6           90.7           85.7          74.433333      True      1
# S033        Kenneth Kapenda   19.0  Male    Grade 11B  49.7        46.2           89.8           88.3          61.900000      True      1
# S035        Rodrick Phiri     18.0  Male    Grade 11B  70.4        92.6           99.1           89.2          87.366667      True      1
# S036        Ivy Kaluba        19.0  Male    Grade 11A  63.9        47.9           58.3           78.2          56.700000      True      1
# S037        Ronald Chansa     16.0  Male    Grade 12B  78.0        56.2           59.9           96.3          64.700000      True      1
# S038        Gloria Mbewe      19.0  Male    Grade 11A  92.8        41.3           47.2           90.6          60.433333      True      1
# S041        Ethel Mwape       18.0  Male    Grade 11B  42.7        92.4           49.3           86.7          61.466667      True      1
# S042        Martin Chileshe   19.0  Female  Grade 11A  89.6        69.7           38.3           99.2          65.866667      True      1
# S043        Tobias Lungu      18.0  Male    Grade 12B  42.7        72.3           73.7           76.8          62.900000      True      1
# S044        Bridget Zulu      18.0  Male    Grade 11A  69.6        92.5           32.3           85.0          64.800000      True      1
# S045        Justine Mwansa    16.0  Male    Grade 11B  60.1        53.7           77.7           89.4          63.833333      True      1
# S049        Gift Banda        19.0  Female  Grade 11A  80.4        85.1           33.5           78.9          66.333333      True      1
# S050        Agnes Mumba       17.0  Male    Grade 11A  38.4        67.0           79.9           90.4          61.766667      True      1
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      34
# Female    16
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Student_ID        0
# Name              0
# Age              10
# Gender            0
# Class             0
# Math_Score        5
# English_Score     2
# Science_Score     8
# Attendance_%      0
# Average_Score     0
# Passed            0
# dtype: int64

# %%
df.groupby('Gender')['Age'].mean()
# Out:
# Gender
# Female    17.538462
# Male      17.851852
# Name: Age, dtype: float64

# %%
corr_matrix = df.corr()
print(corr_matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 corr_matrix = df.corr()
#       2 print(corr_matrix)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'S001'

# %%
corr_matrix = df.corr('Age', 'Math_score')
print(corr_matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 corr_matrix = df.corr('Age', 'Math_score')
#       2 print(corr_matrix)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'S001'

# %%
data = { "A": [1,2,3,4,5],
         "B": [5,4,3,2,1],
         "C": [10,12,11,13,15]
       }

df = pd.DataFrame(data)

corr_matrix = df.corr()
print(corr_matrix)
# Out:
#           A         B         C
# A  1.000000 -1.000000  0.904194
# B -1.000000  1.000000 -0.904194
# C  0.904194 -0.904194  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Age'], bins=20, kde=True)
plt.title("Histogram of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 4
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 4 sns.histplot(df['Age'], bins=20, kde=True)
#       5 plt.title("Histogram of Age")
#       6 plt.xlabel("Age")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Age'
