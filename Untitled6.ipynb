# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset('titanic')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
import matplotlib.pyplot as plt

df.isnull().sum().plot(kind='bar', color='tomato')
plt.title("Missing Values per Feature")
plt.ylabel("Count")
plt.show()

# %%
df['age'].fillna(df['age'].median(), inplace=True)
# Out:
# C:\Users\mudo\AppData\Local\Temp\ipykernel_31824\1654433547.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# Identify outliers in the 'fare' column
Q1, Q3 = df['fare'].quantile([0.25, 0.75])
print('Q1: ', Q1 )
print('Q3: ', Q3)
IQR = Q3 - Q1
print('IQR: ', IQR)

# Define bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print('lower_bound: ', lower_bound)
print('upper_bound: ', upper_bound)

# Filter outliers
outliers = df[(df['fare'] < lower_bound) | (df['fare'] > upper_bound)]
print("Number of outliers:", len(outliers))
print(outliers['fare'])
# Out:
# Q1:  7.9104
# Q3:  31.0
# IQR:  23.0896
# lower_bound:  -26.724
# upper_bound:  65.6344
# Number of outliers: 116
# 1       71.2833
# 27     263.0000
# 31     146.5208
# 34      82.1708
# 52      76.7292
#          ...
# 846     69.5500
# 849     89.1042
# 856    164.8667
# 863     69.5500
# 879     83.1583
# Name: fare, Length: 116, dtype: float64

# %%
plt.figure(figsize=(6,4))
plt.boxplot(df['fare'], vert=False)
plt.title("Fare Distribution with Outliers")
plt.xlabel("Fare")
plt.show()

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
pd.crosstab(df['sex'], df['embark_town'])
# Out:
# embark_town  Cherbourg  Queenstown  Southampton
# sex
# female              73          36          203
# male                95          41          441

# %%
pd.crosstab(df['sex'], df['embark_town'], normalize='index')
# Out:
# embark_town  Cherbourg  Queenstown  Southampton
# sex
# female        0.233974    0.115385     0.650641
# male          0.164645    0.071057     0.764298

# %%
pd.crosstab( [df['sex'], df['pclass']], # row categories 
	df['survived'],
	normalize='index' 
)
# Out:
# survived              0         1
# sex    pclass
# female 1       0.031915  0.968085
#        2       0.078947  0.921053
#        3       0.500000  0.500000
# male   1       0.631148  0.368852
#        2       0.842593  0.157407
#        3       0.864553  0.135447

# %%
sns.heatmap(pd.crosstab(df['sex'], df['survived'], normalize='index'), annot=True, cmap='coolwarm')
plt.title("Survival Proportion by Gender")
plt.show()

# %%
df.groupby('pclass')['age'].mean()
# Out:
# pclass
# 1    36.812130
# 2    29.765380
# 3    25.932627
# Name: age, dtype: float64

# %%
df.groupby('pclass').agg({
    'age': 'mean',
    'fare': 'mean',
    'survived': 'mean'
})
# Out:
#               age       fare  survived
# pclass
# 1       36.812130  84.154687  0.629630
# 2       29.765380  20.662183  0.472826
# 3       25.932627  13.675550  0.242363

# %%
df.groupby('pclass').agg({
    'age': ['mean', 'median'],
    'fare': ['mean', 'std'],
    'survived': 'mean'
})
# Out:
#               age              fare             survived
#              mean median       mean        std      mean
# pclass
# 1       36.812130   35.0  84.154687  78.380373  0.629630
# 2       29.765380   28.0  20.662183  13.417399  0.472826
# 3       25.932627   28.0  13.675550  11.778142  0.242363

# %%
df.groupby('pclass')['survived'].mean().plot(kind='bar', title='Survival Rate by Passenger Class') 
plt.ylabel('Survival Rate') 
plt.show()

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['embarked'].value_counts()
# Out:
# embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='embarked', hue='pclass', data=df)
plt.title('Passenger Count by Embarkation Port')
plt.xlabel('Embarkation Port')
plt.ylabel('Number of Passengers')
plt.show()

# %%
sns.countplot(x='embarked', hue='survived', data=df) 
plt.title('Survival by Embarkation Port') 
plt.xlabel('Embarkation Port') 
plt.ylabel('Passenger Count') 
plt.legend(title='Survived', labels=['No', 'Yes']) 
plt.show()

# %%
df[['age', 'fare']].head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
sns.lmplot(x='age', y='fare', hue = 'sex', data=df) 
plt.title('Age vs Fare — Regression Line') 
plt.xlabel('Age') 
plt.ylabel('Fare') 
plt.show()

# %%
df[['age','fare']].cov()
# Out:
#              age         fare
# age   211.019125    73.849030
# fare   73.849030  2469.436846

# %%
df[['age', 'fare']].cov()
# Out:
#              age         fare
# age   211.019125    73.849030
# fare   73.849030  2469.436846

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
print(df)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
z = (df['age'] - df['age'].mean()) / df['age'].std() 
sns.histplot(z, kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>
