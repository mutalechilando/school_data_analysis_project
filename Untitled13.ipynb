# %%
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset('titanic')

male = df[df['sex'] == 'male']['survived']
female = df[df['sex'] == 'female']['survived']

stats.ttest_ind(male, female, nan_policy='omit')
# Out:
# TtestResult(statistic=np.float64(-19.297816550123354), pvalue=np.float64(1.4060661308802594e-69), df=np.float64(889.0))

# %%
sns.kdeplot(male, label='Male')
sns.kdeplot(female, label='Female')
plt.legend()
plt.show()
